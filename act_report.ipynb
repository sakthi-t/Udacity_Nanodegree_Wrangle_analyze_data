# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ## Dataframe for Data Analysis & Visualization
#
# - I make a copy of the wrangled data and store it in a dataframe df_test
# - I ensure that the df_test doesn't have any duplicates
# - Further in df_test the headers are variables, every row consists of values and put together it is a table

# %% [markdown]
# ## Developing Insights
#
# - The insights are simple statements or it could be considered as yes or no questions
#
# ## Insights
#
# - Top 5 dog breeds as per p1
# - The relationship between rating and retweets
# - The relationship between retweets and favourites
# - The rating denominator is not a constant value of 10
#
# ## Specific Answers or Observations Based on Insights
#
# - The top five dog breeds are
#     - golden_retriever 119 numbers
#     - pembroke 77 numbers
#     - Labrador_retriever 75 numbers
#     - Chihuahua 50
#     - Pug 39
#
# - The co relation between rating and retweets are not strong
# - The co relation between retweets and favourites are not strong
# - The maximum rating is 3.43 and the minimum rating is 0.2

# %% [markdown]
# ## Visualizations
#
# ### Histogram of dog breeds as per p1
#
# ![histogram.png](attachment:histogram.png)
#
# ### Scatter plot of retweets and favourites

# %% [markdown]
# ![scatter_fav_retweets.png](attachment:scatter_fav_retweets.png)

# %% [markdown]
# ## Scatter Plot of Retweets and Ratings
#
# ![retweets_rating.png](attachment:retweets_rating.png)
